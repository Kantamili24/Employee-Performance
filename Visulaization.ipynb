# %%
import pandas
import matplotlib.pyplot as plt

# %%
#Importing cleaned data
df_data = pandas.read_csv('C:/Users/Admin/IABAC_Project/data/processed/INX_Future_Inc_Employee_Performance_full_dataset_predicted_performance.csv')
df_data.hist(column = 'EmpJobSatisfaction')
df_data.hist(column = 'OverTime_Yes')
df_data.hist(column = 'PerformanceRating')
#plt.show()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000DD17748888>]],
#       dtype=object)

# %% [markdown]
# ### The first bar graph shows the distribution of the employees based on the Emp_Job_satisfaction. Majority employees fall in the satisfaction level of 3 (High) and 4(Very High). That mean approximately 700 employees are Highly or very highly satisfied with their job. Since this predictor variable has a positive correlation with the employee performance rating, the same is reflected in the third bar graph where 1100 employees have 3 rating.
#
# ### The second predictor variable that has also positive correlation with employee performance is Overtime (No Overtime). Approximately 850 employees don't do overtime which is positively correlated with 1200 high performers.
